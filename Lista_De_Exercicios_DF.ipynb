# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **1. Reformule a série a seguir em um dataframe com 7 linhas e 5 colunas.**

# %%
ser = pd.Series(np.random.randint(1, 10,35))

# %%
dados = np.random.randint(1, 10,35)
ser=pd.DataFrame(pd.Series(dados)).values.reshape(7,5)
ser
# Out:
# array([[8, 8, 6, 2, 3],
#        [1, 1, 5, 9, 9],
#        [3, 1, 9, 2, 4],
#        [9, 6, 3, 6, 1],
#        [7, 5, 3, 7, 4],
#        [8, 2, 2, 9, 5],
#        [3, 4, 3, 3, 3]])

# %% [markdown]
# **2. Concatene ser1 e ser2 vertical e horizontalmente para formar um dataframe.**

# %%
ser1 = pd.Series(range(5))
ser2 = pd.Series(list('abcde'))

# %%
pd.concat([ser1,ser2],ignore_index=True)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# 5    a
# 6    b
# 7    c
# 8    d
# 9    e
# dtype: object

# %% [markdown]
# **3. Importe as colunas ’crim’ e ’medv’ do conjunto de dados do BostonHousing como
# um dataframe.**

# %%
df=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
df
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df1=pd.DataFrame(df['crim'])
df1
# Out:
#          crim
# 0     0.00632
# 1     0.02731
# 2     0.02729
# 3     0.03237
# 4     0.06905
# 5     0.02985
# 6     0.08829
# 7     0.14455
# 8     0.21124
# 9     0.17004
# 10    0.22489
# 11    0.11747
# 12    0.09378
# 13    0.62976
# 14    0.63796
# 15    0.62739
# 16    1.05393
# 17    0.78420
# 18    0.80271
# 19    0.72580
# 20    1.25179
# 21    0.85204
# 22    1.23247
# 23    0.98843
# 24    0.75026
# 25    0.84054
# 26    0.67191
# 27    0.95577
# 28    0.77299
# 29    1.00245
# ..        ...
# 476   4.87141
# 477  15.02340
# 478  10.23300
# 479  14.33370
# 480   5.82401
# 481   5.70818
# 482   5.73116
# 483   2.81838
# 484   2.37857
# 485   3.67367
# 486   5.69175
# 487   4.83567
# 488   0.15086
# 489   0.18337
# 490   0.20746
# 491   0.10574
# 492   0.11132
# 493   0.17331
# 494   0.27957
# 495   0.17899
# 496   0.28960
# 497   0.26838
# 498   0.23912
# 499   0.17783
# 500   0.22438
# 501   0.06263
# 502   0.04527
# 503   0.06076
# 504   0.10959
# 505   0.04741
#
# ...

# %%
df2=pd.DataFrame(df['medv'])
df2
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# 5    28.7
# 6    22.9
# 7    27.1
# 8    16.5
# 9    18.9
# 10   15.0
# 11   18.9
# 12   21.7
# 13   20.4
# 14   18.2
# 15   19.9
# 16   23.1
# 17   17.5
# 18   20.2
# 19   18.2
# 20   13.6
# 21   19.6
# 22   15.2
# 23   14.5
# 24   15.6
# 25   13.9
# 26   16.6
# 27   14.8
# 28   18.4
# 29   21.0
# ..    ...
# 476  16.7
# 477  12.0
# 478  14.6
# 479  21.4
# 480  23.0
# 481  23.7
# 482  25.0
# 483  21.8
# 484  20.6
# 485  21.2
# 486  19.1
# 487  20.6
# 488  15.2
# 489   7.0
# 490   8.1
# 491  13.6
# 492  20.1
# 493  21.8
# 494  24.5
# 495  23.1
# 496  19.7
# 497  18.3
# 498  21.2
# 499  17.5
# 500  16.8
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %% [markdown]
# **4. Renomeie a coluna Type como CarType em df e substitua o ’.’ nos nomes das
# colunas com ’_’.**

# %%
newdf=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
newdf.rename(columns={'Type':'CarType'})#,inplace=True faria mudar definitivamente
newdf.rename(columns={".":"_"})
# Out:
#    Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0         Acura        Integra    Small       12.9   15.9       18.8
# 1           NaN         Legend  Midsize       29.2   33.9       38.7
# 2          Audi             90  Compact       25.9   29.1       32.3
# 3          Audi            100  Midsize        NaN   37.7       44.6
# 4           BMW           535i  Midsize        NaN   30.0        NaN
# 5         Buick        Century  Midsize       14.2   15.7       17.3
# 6         Buick        LeSabre    Large       19.9   20.8        NaN
# 7         Buick     Roadmaster    Large       22.6   23.7       24.9
# 8         Buick        Riviera  Midsize       26.3   26.3       26.3
# 9      Cadillac        DeVille    Large       33.0   34.7       36.3
# 10     Cadillac        Seville  Midsize       37.5   40.1       42.7
# 11    Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 12    Chevrolet        Corsica  Compact       11.4   11.4       11.4
# ...

# %% [markdown]
# **5. Verifique se o dataframe tem algum valor ausente**

# %%
newdf=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
newdf.isnull()
# Out:
#     Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 0          False  False  False      False  False      False     False
# 1           True  False  False      False  False      False     False
# 2          False  False  False      False  False      False     False
# 3          False  False  False       True  False      False     False
# 4          False  False  False       True  False       True     False
# 5          False  False  False      False  False      False     False
# 6          False  False  False      False  False       True     False
# 7          False  False  False      False  False      False     False
# 8          False  False  False      False  False      False     False
# 9          False  False  False      False  False      False     False
# 10         False  False  False      False  False      False     False
# 11         False  False  False      False  False      False     False
# ...

# %% [markdown]
# **6. Conte o número de valores ausentes em cada coluna do df . Qual coluna tem o
# número máximo de valores ausentes?**

# %%
newdf.isnull().sum().sort_values(ascending=False)
# Out:
# Luggage.room          19
# MPG.city               9
# Fuel.tank.capacity     8
# Min.Price              7
# Weight                 7
# DriveTrain             7
# Horsepower             7
# Rev.per.mile           6
# AirBags                6
# Width                  6
# Man.trans.avail        5
# Origin                 5
# Turn.circle            5
# Max.Price              5
# Cylinders              5
# Length                 4
# Rear.seat.room         4
# Manufacturer           4
# Type                   3
# Make                   3
# RPM                    3
# MPG.highway            2
# EngineSize             2
# Price                  2
# Passengers             2
# Wheelbase              1
# Model                  1
# dtype: int64

# %% [markdown]
# **7. Obtenha a primeira coluna ’a’ em df como um dataframe (em vez de uma série).**

# %%
df = pd.DataFrame(np.arange(20).reshape(-1,5), columns=list('abcde'))
df
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
dfa = pd.DataFrame(df['a'])
dfa
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %% [markdown]
# **8. Como alterar a ordem das colunas de um dataframe? Para isso, respondam as três
# questões:**

# %% [markdown]
# (a) Em df, troque as colunas ’a’ e ’c’.

# %%
df[['c','b','a','d','e']]
# Out:
#     c   b   a   d   e
# 0   2   1   0   3   4
# 1   7   6   5   8   9
# 2  12  11  10  13  14
# 3  17  16  15  18  19

# %% [markdown]
# (b) Crie uma função genérica para trocar duas colunas, sem codificar os nomes das
# colunas.

# %%
def Trocar_colunas(x,y):
    df = df.rename[columns={'x':'y', 'y':'x'}]
    return df

# %% [markdown]
# (c) Classifique as colunas em ordem alfabética inversa, ou seja, colume ’e’ primeiro
# até a coluna ’a’ last

# %%
df[['e','d','c','b','a']]
# Out:
#     e   d   c   b   a
# 0   4   3   2   1   0
# 1   9   8   7   6   5
# 2  14  13  12  11  10
# 3  19  18  17  16  15

# %% [markdown]
# **9. Altere as configurações de exibição de Pandas ao imprimir o dataframe df mostre
# no máximo 10 linhas e 10 colunas.**

# %%
newdf.iloc[:10,:10]
# Out:
#   Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura     Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN      Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi          90  Compact       25.9   29.1       32.3      20.0
# 3         Audi         100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW        535i  Midsize        NaN   30.0        NaN      22.0
# 5        Buick     Century  Midsize       14.2   15.7       17.3      22.0
# 6        Buick     LeSabre    Large       19.9   20.8        NaN      19.0
# 7        Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 8        Buick     Riviera  Midsize       26.3   26.3       26.3      19.0
# 9     Cadillac     DeVille    Large       33.0   34.7       36.3      16.0
#
#    MPG.highway             AirBags DriveTrain
# 0         31.0                None      Front
# 1         25.0  Driver & Passenger      Front
# ...

# %% [markdown]
# **10. A partir de df , filtre o ’Manufacturer’, ’Model’ e ’Type’ para cada 20 linhas,
# começando em 1º (linha 0).**

# %%
newdf[['Manufacturer','Model','Type']].loc[:20]
# Out:
#    Manufacturer       Model     Type
# 0         Acura     Integra    Small
# 1           NaN      Legend  Midsize
# 2          Audi          90  Compact
# 3          Audi         100  Midsize
# 4           BMW        535i  Midsize
# 5         Buick     Century  Midsize
# 6         Buick     LeSabre    Large
# 7         Buick  Roadmaster    Large
# 8         Buick     Riviera  Midsize
# 9      Cadillac     DeVille    Large
# 10     Cadillac     Seville  Midsize
# 11    Chevrolet    Cavalier  Compact
# 12    Chevrolet     Corsica  Compact
# 13    Chevrolet      Camaro   Sporty
# 14    Chevrolet      Lumina  Midsize
# 15    Chevrolet  Lumina_APV      Van
# 16    Chevrolet       Astro      Van
# 17    Chevrolet     Caprice    Large
# 18    Chevrolet    Corvette   Sporty
# 19          NaN    Concorde    Large
# 20     Chrysler     LeBaron  Compact

# %% [markdown]
# **11. Obtenha as duas últimas linhas de df cuja soma da linha é maior que 100.**

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1,4))
print(df.loc[14].sum())
print(df.loc[14].sum())
# Out:
# 128
# 128

# %% [markdown]
# **12. Troque as linhas 1 e 2 em df.**

# %%
df = pd.DataFrame(np.arange(25).reshape(5, -1))
df.index=[0,2,1,3,4]
df
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 2   5   6   7   8   9
# 1  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
